# %% [markdown]
# <a href="https://colab.research.google.com/github/sak-shi-collab/8_SAKSHI_D2/blob/main/api_to_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     56.3199
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     39.5995
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     21.1650
# 3  The true story of how businessman Oskar Schind...   1993-12-15     23.7852
# 4  The defense and the prosecution have rested an...   1957-04-10     16.5541
#
#    vote_average  vote_count
# 0         8.700       29936
# 1         8.687       22615
# 2         8.572       13697
# 3         8.567       17219
# 4         8.600        9821

# %%
df= pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
all_dfs = []
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    all_dfs.append(temp_df)

df = pd.concat(all_dfs, ignore_index=True)

# %%
df.shape
# Out:
# (8560, 7)

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            20 non-null     int64
#  1   title         20 non-null     object
#  2   overview      20 non-null     object
#  3   release_date  20 non-null     object
#  4   popularity    20 non-null     float64
#  5   vote_average  20 non-null     float64
#  6   vote_count    20 non-null     int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.2+ KB

# %%
df
# Out:
#           id                     title  \
# 0        278  The Shawshank Redemption
# 1        238             The Godfather
# 2        240     The Godfather Part II
# 3        424          Schindler's List
# 4        389              12 Angry Men
# ...      ...                       ...
# 8555  123109              No One Lives
# 8556  930600           The Deliverance
# 8557  921636              The Out-Laws
# 8558  800345                    Carter
# 8559  672582            The Deep House
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# ...

# %%
df.shape
# Out:
# (8560, 7)

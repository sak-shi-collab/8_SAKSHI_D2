# %% [markdown]
# <a href="https://colab.research.google.com/github/sak-shi-collab/8_SAKSHI_D2/blob/main/univariate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('train.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_7798/1000595957.py in <cell line: 0>()
# ----> 1 df = pd.read_csv('train.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# ...

# %%
print("First 5 rows of the DataFrame:")
display(df.head())
# Out:
# First 5 rows of the DataFrame:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7798/4152321524.py in <cell line: 0>()
#       1 print("First 5 rows of the DataFrame:")
# ----> 2 display(df.head())
#
# NameError: name 'df' is not defined

# %%
print("DataFrame Info (data types and non-null counts):")
df.info()
# Out:
# DataFrame Info (data types and non-null counts):
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7798/2550104498.py in <cell line: 0>()
#       1 print("DataFrame Info (data types and non-null counts):")
# ----> 2 df.info()
#
# NameError: name 'df' is not defined

# %%
print("Descriptive statistics for numerical columns:")
display(df.describe())
# Out:
# Descriptive statistics for numerical columns:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7798/1877756989.py in <cell line: 0>()
#       1 print("Descriptive statistics for numerical columns:")
# ----> 2 display(df.describe())
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# CATEGORICAL DATA

# %%
sns.countplot(df['Embarked'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7798/635318707.py in <cell line: 0>()
# ----> 1 sns.countplot(df['Embarked'])
#
# NameError: name 'sns' is not defined

# %% [markdown]
# PIECHART

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')

# %% [markdown]
# NUMERICAL DATA

# %%
1.#HISTOGRAM
import matplotlib.pyplot as plt
plt.hist(df['Age'],bins=5)

# %%
2.#DISPLOT
sns.distplot(df['Age'])

# %%
3.#BOXPLOT
sns.boxplot(df['Age'])

# %%
df['Age'].min()

# %%
df['Age'].max()

# %%
df['Age'].mean()

# %%
df['Age'].skew()
